# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib 
import matplotlib.pyplot as plt
from sqlalchemy import create_engine

# %%
# !pip install sqlalchemy

# %%
China_path = 'China_Data/API_CHN_DS2_en_csv_v2_4670670.csv'
USA_path='US_Data/API_USA_DS2_en_csv_v2_4696777.csv'

# %%
China_df = pd.read_csv(China_path,skiprows=4)
China_df
# Out:
#      Country Name Country Code  \
# 0           China          CHN
# 1           China          CHN
# 2           China          CHN
# 3           China          CHN
# 4           China          CHN
# ...           ...          ...
# 1437        China          CHN
# 1438        China          CHN
# 1439        China          CHN
# 1440        China          CHN
# 1441        China          CHN
#
#                                          Indicator Name     Indicator Code  \
# 0     Intentional homicides, female (per 100,000 fem...  VC.IHR.PSRC.FE.P5
# 1              Battle-related deaths (number of people)        VC.BTL.DETH
# 2                 High-technology exports (current US$)     TX.VAL.TECH.CD
# 3     Merchandise exports to low- and middle-income ...  TX.VAL.MRCH.WR.ZS
# 4     Merchandise exports to low- and middle-income ...  TX.VAL.MRCH.R5.ZS
# ...                                                 ...                ...
# ...

# %%
USA_df = pd.read_csv(USA_path,skiprows=4)
USA_df
# Out:
#        Country Name Country Code  \
# 0     United States          USA
# 1     United States          USA
# 2     United States          USA
# 3     United States          USA
# 4     United States          USA
# ...             ...          ...
# 1437  United States          USA
# 1438  United States          USA
# 1439  United States          USA
# 1440  United States          USA
# 1441  United States          USA
#
#                                          Indicator Name     Indicator Code  \
# 0     Intentional homicides, female (per 100,000 fem...  VC.IHR.PSRC.FE.P5
# 1              Battle-related deaths (number of people)        VC.BTL.DETH
# 2                 High-technology exports (current US$)     TX.VAL.TECH.CD
# 3     Merchandise exports to low- and middle-income ...  TX.VAL.MRCH.WR.ZS
# 4     Merchandise exports to low- and middle-income ...  TX.VAL.MRCH.R5.ZS
# ...                                                 ...                ...
# ...

# %%
China_df2=China_df.dropna()
China_df2
# Out:
#      Country Name Country Code  \
# 13          China          CHN
# 25          China          CHN
# 26          China          CHN
# 28          China          CHN
# 30          China          CHN
# ...           ...          ...
# 953         China          CHN
# 954         China          CHN
# 955         China          CHN
# 956         China          CHN
# 1279        China          CHN
#
#                                          Indicator Name     Indicator Code  \
# 13                    Merchandise imports (current US$)  TM.VAL.MRCH.CD.WT
# 25                                     Urban population        SP.URB.TOTL
# 26                                     Rural population        SP.RUR.TOTL
# 28                                     Population, male  SP.POP.TOTL.MA.IN
# 30    Age dependency ratio, old (% of working-age po...     SP.POP.DPND.OL
# ...                                                 ...                ...
# ...

# %%
USA_df2 = USA_df.dropna()
USA_df2
# USA_df
# Out:
# Empty DataFrame
# Columns: [Country Name, Country Code, Indicator Name, Indicator Code, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, Unnamed: 66]
# Index: []
#
# [0 rows x 67 columns]

# %%
display(China_df.iloc[448])
# Out:
# Country Name                  China
# Country Code                    CHN
# Indicator Name    GDP (current US$)
# Indicator Code       NY.GDP.MKTP.CD
# 1960                    5.97165e+10
#                         ...
# 2017                    1.23104e+13
# 2018                    1.38948e+13
# 2019                    1.42799e+13
# 2020                    1.46877e+13
# 2021                    1.77341e+13
# Name: 448, Length: 66, dtype: object

# %%
display(China_df.iloc[451])
# Out:
# Country Name                                   China
# Country Code                                     CHN
# Indicator Name    Inflation, GDP deflator (annual %)
# Indicator Code                     NY.GDP.DEFL.KD.ZG
# 1960                                             NaN
#                                  ...
# 2017                                         4.23268
# 2018                                         3.49975
# 2019                                          1.2867
# 2020                                        0.491448
# 2021                                         4.37179
# Name: 451, Length: 66, dtype: object

# %%
display(China_df.iloc[431])
# Out:
# Country Name                                                  China
# Country Code                                                    CHN
# Indicator Name    Unemployment, total (% of total labor force) (...
# Indicator Code                                       SL.UEM.TOTL.ZS
# 1960                                                            NaN
#                                         ...
# 2017                                                           4.44
# 2018                                                           4.28
# 2019                                                           4.52
# 2020                                                              5
# 2021                                                          4.817
# Name: 431, Length: 66, dtype: object

# %%
display(China_df.iloc[708])
# Out:
# Country Name                   China
# Country Code                     CHN
# Indicator Name    CO2 emissions (kt)
# Indicator Code        EN.ATM.CO2E.KT
# 1960                             NaN
#                          ...
# 2017                      1.0096e+07
# 2018                     1.05029e+07
# 2019                     1.07072e+07
# 2020                             NaN
# 2021                             NaN
# Name: 708, Length: 66, dtype: object

# %%
display(China_df.iloc[1218])
# Out:
# Country Name                                                 China
# Country Code                                                   CHN
# Indicator Name    Individuals using the Internet (% of population)
# Indicator Code                                      IT.NET.USER.ZS
# 1960                                                           NaN
#                                         ...
# 2017                                                          54.3
# 2018                                                          59.2
# 2019                                                       64.1098
# 2020                                                       70.4048
# 2021                                                           NaN
# Name: 1218, Length: 66, dtype: object

# %%
display(China_df.iloc[532])
# Out:
# Country Name                                                  China
# Country Code                                                    CHN
# Indicator Name    Foreign direct investment, net inflows (% of GDP)
# Indicator Code                                 BX.KLT.DINV.WD.GD.ZS
# 1960                                                            NaN
#                                         ...
# 2017                                                        1.34913
# 2018                                                        1.69391
# 2019                                                        1.31072
# 2020                                                        1.72318
# 2021                                                            NaN
# Name: 532, Length: 66, dtype: object

# %%
display(China_df.iloc[447])
# Out:
# Country Name                      China
# Country Code                        CHN
# Indicator Name    GDP growth (annual %)
# Indicator Code        NY.GDP.MKTP.KD.ZG
# 1960                                NaN
#                           ...
# 2017                             6.9472
# 2018                            6.74977
# 2019                             5.9505
# 2020                             2.2397
# 2021                            8.10979
# Name: 447, Length: 66, dtype: object

# %%
China_list=['NY.GDP.MKTP.CD','NY.GDP.DEFL.KD.ZG','SP.POP.80UP.FE.5Y',
'SP.POP.7074.FE.5Y',
'SP.POP.65UP.MA.IN',
'SP.POP.6569.FE.5Y',
'SP.POP.5559.FE.5Y',
'SP.POP.4549.FE.5Y',
'SP.POP.3539.FE.5Y',
'SP.POP.2529.FE.5Y',
'SP.POP.1564.TO',
'SP.POP.1564.FE.IN',
'SP.POP.1014.FE.5Y',
'SP.POP.0014.TO',
'SP.POP.0014.FE.IN',
'HD.HCI.OVRL.UB', 'HD.HCI.OVRL.LB', 'NY.GDP.MKTP.CD', 'NY.GDP.MKTP.KD.ZG', 'SL.UEM.INTM.MA.ZS', 'SL.UEM.BASC.FE.ZS', 'SL.UEM.1524.ZS', 'SL.UEM.1524.FE.ZS', 'NY.GDP.DEFL.KD.ZG', 'EN.CO2.TRAN.ZS', 'EN.CO2.BLDG.ZS', 'EN.CO2.BLDG.ZS', 'BX.KLT.DINV.WD.GD.ZS'

]
data_china=China_df[China_df['Indicator Code'].isin(China_list)]
data_china
# Out:
#      Country Name Country Code  \
# 31          China          CHN
# 32          China          CHN
# 33          China          CHN
# 34          China          CHN
# 35          China          CHN
# 36          China          CHN
# 37          China          CHN
# 38          China          CHN
# 39          China          CHN
# 40          China          CHN
# 41          China          CHN
# 42          China          CHN
# 43          China          CHN
# 447         China          CHN
# 448         China          CHN
# 451         China          CHN
# 532         China          CHN
# 698         China          CHN
# 699         China          CHN
# 745         China          CHN
# 746         China          CHN
# 747         China          CHN
# 748         China          CHN
# 1049        China          CHN
# 1050        China          CHN
#
#                                          Indicator Name        Indicator Code  \
# ...

# %%
China_list=['NY.GDP.MKTP.CD','NY.GDP.DEFL.KD.ZG','SP.POP.80UP.FE.5Y',
'SP.POP.7074.FE.5Y',
'SP.POP.65UP.MA.IN',
'SP.POP.6569.FE.5Y',
'SP.POP.5559.FE.5Y',
'SP.POP.4549.FE.5Y',
'SP.POP.3539.FE.5Y',
'SP.POP.2529.FE.5Y',
'SP.POP.1564.TO',
'SP.POP.1564.FE.IN',
'SP.POP.1014.FE.5Y',
'SP.POP.0014.TO',
'SP.POP.0014.FE.IN',
'HD.HCI.OVRL.UB', 'HD.HCI.OVRL.LB', 'NY.GDP.MKTP.CD', 'NY.GDP.MKTP.KD.ZG', 'SL.UEM.INTM.MA.ZS', 'SL.UEM.BASC.FE.ZS', 'SL.UEM.1524.ZS', 'SL.UEM.1524.FE.ZS', 'NY.GDP.DEFL.KD.ZG', 'EN.CO2.TRAN.ZS', 'EN.CO2.BLDG.ZS', 'EN.CO2.BLDG.ZS', 'BX.KLT.DINV.WD.GD.ZS'

]
data_USA=USA_df[USA_df['Indicator Code'].isin(China_list)]
data_USA
# Out:
#        Country Name Country Code  \
# 31    United States          USA
# 32    United States          USA
# 33    United States          USA
# 34    United States          USA
# 35    United States          USA
# 36    United States          USA
# 37    United States          USA
# 38    United States          USA
# 39    United States          USA
# 40    United States          USA
# 41    United States          USA
# 42    United States          USA
# 43    United States          USA
# 732   United States          USA
# 733   United States          USA
# 734   United States          USA
# 735   United States          USA
# 884   United States          USA
# 1024  United States          USA
# 1025  United States          USA
# 1028  United States          USA
# 1168  United States          USA
# 1169  United States          USA
# 1395  United States          USA
# 1396  United States          USA
#
#                                          Indicator Name        Indicator Code  \
# ...

# %%
# data=data_china.drop(data_china['1960', '1961'], axis=1)
# data=data_china.drop(columns=['1960', '1990'])
# data
china_data=data_china.drop(data_china.iloc[:, 4:31], inplace=False, axis=1)
china_data
# Out:
#      Country Name Country Code  \
# 31          China          CHN
# 32          China          CHN
# 33          China          CHN
# 34          China          CHN
# 35          China          CHN
# 36          China          CHN
# 37          China          CHN
# 38          China          CHN
# 39          China          CHN
# 40          China          CHN
# 41          China          CHN
# 42          China          CHN
# 43          China          CHN
# 447         China          CHN
# 448         China          CHN
# 451         China          CHN
# 532         China          CHN
# 698         China          CHN
# 699         China          CHN
# 745         China          CHN
# 746         China          CHN
# 747         China          CHN
# 748         China          CHN
# 1049        China          CHN
# 1050        China          CHN
#
#                                          Indicator Name        Indicator Code  \
# ...

# %%
USA_data=data_USA.drop(data_USA.iloc[:, 4:34], inplace=False, axis=1)
USA_data
# Out:
#        Country Name Country Code  \
# 31    United States          USA
# 32    United States          USA
# 33    United States          USA
# 34    United States          USA
# 35    United States          USA
# 36    United States          USA
# 37    United States          USA
# 38    United States          USA
# 39    United States          USA
# 40    United States          USA
# 41    United States          USA
# 42    United States          USA
# 43    United States          USA
# 732   United States          USA
# 733   United States          USA
# 734   United States          USA
# 735   United States          USA
# 884   United States          USA
# 1024  United States          USA
# 1025  United States          USA
# 1028  United States          USA
# 1168  United States          USA
# 1169  United States          USA
# 1395  United States          USA
# 1396  United States          USA
#
#                                          Indicator Name        Indicator Code  \
# ...

# %%
USA_data=USA_data.drop(columns=['Unnamed: 66'])
USA_data
# Out:
#        Country Name Country Code  \
# 31    United States          USA
# 32    United States          USA
# 33    United States          USA
# 34    United States          USA
# 35    United States          USA
# 36    United States          USA
# 37    United States          USA
# 38    United States          USA
# 39    United States          USA
# 40    United States          USA
# 41    United States          USA
# 42    United States          USA
# 43    United States          USA
# 732   United States          USA
# 733   United States          USA
# 734   United States          USA
# 735   United States          USA
# 884   United States          USA
# 1024  United States          USA
# 1025  United States          USA
# 1028  United States          USA
# 1168  United States          USA
# 1169  United States          USA
# 1395  United States          USA
# 1396  United States          USA
#
#                                          Indicator Name        Indicator Code  \
# ...

# %%
protocol = 'postgresql'
username = 'postgres'
password = 'postgres'
host = 'localhost'
port = 5432
database_name = 'WorldBank_db'
rds_connection_string = f'{protocol}://{username}:{password}@{host}:{port}/{database_name}'
engine = create_engine(rds_connection_string)
